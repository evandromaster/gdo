# %%
import pandas as pd
import numpy as np
dir_envol = r'I:\Meganz\PMMG\MySql\10 - Tbl_dimensao\gdo\tbl_envolvidos.csv'#Home
#dir_envol = r'C:\Users\Geo\Documents\MEGAsync\MySql\10 - Tbl_dimensao\gdo\tbl_envolvidos.csv'#Office
df_envol = pd.read_csv(dir_envol, sep=";", encoding='utf8', low_memory =False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1aec1138aa57> in <module>
#       3 dir_envol = r'I:\Meganz\PMMG\MySql\10 - Tbl_dimensao\gdo\tbl_envolvidos.csv'#Home
#       4 #dir_envol = r'C:\Users\Geo\Documents\MEGAsync\MySql\10 - Tbl_dimensao\gdo\tbl_envolvidos.csv'#Office
# ----> 5 df_envol = pd.read_csv(dir_envol, sep=";", encoding='utf8', low_memory =False)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: 'I:\\Meganz\\PMMG\\MySql\\10 - Tbl_dimensao\\gdo\\tbl_envolvidos.csv'

# %%
df_envol.columns
# Out:
# Index(['Número REDS', 'Órgão Unidade Registro', 'Unidade Área Militar',
#        'Unid Registro Nível 6', 'Código Subclasse Nat Principal',
#        'Tentado/Consumado Nat Principal', 'Código Subclasse Natureza',
#        'Tentado/Consumado', 'Grau Lesão', 'Tipo Envolvimento',
#        'Grupo Tipo Envolvimento', 'Prisão / Apreensão', 'Data Fato',
#        'Horário Fato', 'Data Última Atualização',
#        'Logradouro Ocorrência - Tipo', 'Logradouro Ocorrência',
#        'Logradouro Ocorrência Não Cadastrado', 'Logradouro Cruzamento',
#        'Logradouro Cruzamento Não Cadastrado', 'Número Logradouro', 'Bairro',
#        'Bairro Não Cadastrado', 'Complemento Endereço', 'Ponto de Referência',
#        'Município', 'Latitude', 'Longitude', 'Nome Envolvido',
#        'Data Nascimento', 'Sexo', 'Cútis', 'Idade Aparente', 'Estado Civil',
#        'Ocupação Atual', 'Escolaridade', 'Logradouro Envolvido',
#        'Bairro Envolvido', 'Tipo Logradouro Envolvido', 'Município Envolvido',
#        'Qtde Envolvidos'],
#       dtype='object')

# %%
df_envol['Idade Aparente'].describe()
# Out:
# count    12041.000000
# mean        33.870360
# std         15.208044
# min          0.000000
# 25%         22.000000
# 50%         31.000000
# 75%         43.000000
# max         98.000000
# Name: Idade Aparente, dtype: float64

# %%
df_envol['Idade Aparente'].min()
# Out:
# 0.0

# %%
#df_envol[df_envol.'Estado Civil'== 'SOLTEIRO'.'Idade Aparente'].max() 
#notação por ponto  vale  quando o nome do campo  não tem espaço
df_envol[df_envol['Estado Civil']== 'SOLTEIRO']['Idade Aparente'].max()
# Out:
# 87.0

# %%
df_envol.shape
# Out:
# (12244, 41)

# %%
#df_crimes.filter(like ='Cód.').head()

df_envol[df_envol['Estado Civil'].isin(['SOLTEIRO'])]['Idade Aparente'].max()
# Out:
# 87.0

# %%
df_envol[['Estado Civil', 'Idade Aparente']].groupby(['Estado Civil']).mean()
# Out:
#                               Idade Aparente
# Estado Civil
# CASADO                             43.885956
# DIVORCIADO                         46.738636
# ESTADO CIVIL - IGNORADO            33.022979
# ESTADO CIVIL - NAO DECLARADO       35.805882
# PREENCHIMENTO OPCIONAL             40.733333
# SEPARADO JUDICIALMENTE             43.800000
# SOLTEIRO                           25.591324
# UNIAO ESTAVEL                      33.786575
# VIUVO                              61.441441

# %%
df_envol[['Estado Civil', 'Escolaridade','Idade Aparente']].groupby(['Estado Civil', 'Escolaridade']).mean().round(1)
# Out:
#                                                                        Idade Aparente
# Estado Civil            Escolaridade
# CASADO                  ALFABETIZADO                                             45.8
#                         ANALFABETO                                               52.1
#                         ENSINO FUNDAMENTAL COMPLETO (8 ANOS ESTUDO)              43.0
#                         ENSINO FUNDAMENTAL INCOMPLETO (8 ANOS ESTUDO)            48.2
#                         ENSINO MEDIO COMPLETO (2º GRAU)                          40.4
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       37.9
#                         ESCOLARIDADE - IGNORADA                                  45.0
#                         OUTROS - ESCOLARIDADE                                    44.1
#                         POS-GRADUACAO                                            44.3
#                         SUPERIOR COMPLETO                                        40.7
#                         SUPERIOR INCOMPLETO                                      37.2
# DIVORCIADO              ALFABETIZADO                                             47.3
#                         ANALFABETO                                               50.3
#                         ENSINO FUNDAMENTAL COMPLETO (8 ANOS ESTUDO)              46.7
#                         ENSINO FUNDAMENTAL INCOMPLETO (8 ANOS ESTUDO)            50.2
#                         ENSINO MEDIO COMPLETO (2º GRAU)                          45.5
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       44.5
#                         ESCOLARIDADE - IGNORADA                                  46.0
#                         OUTROS - ESCOLARIDADE                                    37.6
#                         POS-GRADUACAO                                            52.5
#                         SUPERIOR COMPLETO                                        46.4
#                         SUPERIOR INCOMPLETO                                      43.6
# ESTADO CIVIL - IGNORADO ALFABETIZADO                                             35.0
#                         ANALFABETO                                               22.5
#                         ENSINO FUNDAMENTAL COMPLETO (8 ANOS ESTUDO)              46.6
#                         ENSINO FUNDAMENTAL INCOMPLETO (8 ANOS ESTUDO)            25.2
#                         ENSINO MEDIO COMPLETO (2º GRAU)                          37.0
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       36.9
#                         ESCOLARIDADE - IGNORADA                                  32.4
#                         OUTROS - ESCOLARIDADE                                    30.3
# ...                                                                               ...
# SOLTEIRO                ENSINO MEDIO COMPLETO (2º GRAU)                          27.5
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       21.9
#                         ESCOLARIDADE - IGNORADA                                  24.5
#                         OUTROS - ESCOLARIDADE                                    21.1
#                         POS-GRADUACAO                                            30.8
#                         PREENCHIMENTO OPCIONAL                                   67.0
#                         SUPERIOR COMPLETO                                        31.5
#                         SUPERIOR INCOMPLETO                                      24.8
# UNIAO ESTAVEL           ALFABETIZADO                                             35.6
#                         ANALFABETO                                               45.3
#                         ENSINO FUNDAMENTAL COMPLETO (8 ANOS ESTUDO)              31.9
#                         ENSINO FUNDAMENTAL INCOMPLETO (8 ANOS ESTUDO)            34.8
#                         ENSINO MEDIO COMPLETO (2º GRAU)                          31.7
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       31.2
#                         ESCOLARIDADE - IGNORADA                                  32.9
#                         OUTROS - ESCOLARIDADE                                    33.5
#                         POS-GRADUACAO                                            42.5
#                         SUPERIOR COMPLETO                                        36.4
#                         SUPERIOR INCOMPLETO                                      33.4
# VIUVO                   ALFABETIZADO                                             65.1
#                         ANALFABETO                                               73.0
#                         ENSINO FUNDAMENTAL COMPLETO (8 ANOS ESTUDO)              56.4
#                         ENSINO FUNDAMENTAL INCOMPLETO (8 ANOS ESTUDO)            59.6
#                         ENSINO MEDIO COMPLETO (2º GRAU)                          54.2
#                         ENSINO MEDIO INCOMPLETO ( 2º GRAU)                       60.5
#                         ESCOLARIDADE - IGNORADA                                  64.3
#                         OUTROS - ESCOLARIDADE                                    63.0
#                         POS-GRADUACAO                                            79.0
#                         SUPERIOR COMPLETO                                        54.4
#                         SUPERIOR INCOMPLETO                                      61.0
#
# [90 rows x 1 columns]

# %%
colunas = ['Estado Civil', 'Idade Aparente']
df_envol[((df_envol['Idade Aparente']>=0)&
          (df_envol['Idade Aparente']<=1000))&
          (df_envol['Estado Civil'].isin(['CASADO', 'SOLTEIRO', 'VIUVO']))
        
        ][colunas].groupby(df_envol['Estado Civil']).mean().round(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5c619ea98d5> in <module>
#       1 colunas = ['Estado Civil', 'Idade Aparente']
# ----> 2 df_envol[((df_envol['Idade Aparente']>=0)&
#       3           (df_envol['Idade Aparente']<=1000))&
#       4           (df_envol['Estado Civil'].isin(['CASADO', 'SOLTEIRO', 'VIUVO']))
#       5
#
# NameError: name 'df_envol' is not defined
