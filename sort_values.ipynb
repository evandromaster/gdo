# %%
import pandas as pd
import numpy as np

dir_crimes = r'I:\Meganz\PMMG\MySql\10 - Tbl_dimensao\gdo\tbl_crimes.csv'#Home
df_crimes = pd.read_csv(dir_crimes, sep=";", encoding='utf8', low_memory =False)

# %%
df_crimes.sort_values('Unid Digitação Nível 6', inplace = True)

# %%
df_crimes.sort_values(by = ['Código Subclasse Nat Principal', 'Unid Digitação Nível 6'])
# Out:
#               Número REDS Órgão Unidade Registro  \
# 20559  2019-001874741-001        POLICIA MILITAR
# 22949  2019-062421817-001        POLICIA MILITAR
# 15552  2019-012545627-001          POLICIA CIVIL
# 23571  2019-005029460-001        POLICIA MILITAR
# 23570  2020-007772815-001        POLICIA MILITAR
# 23507  2019-035979170-001        POLICIA MILITAR
# 23543  2019-016904340-001        POLICIA MILITAR
# 19714  2019-030889630-001        POLICIA MILITAR
# 23478  2019-013014177-001        POLICIA MILITAR
# 23454  2020-020158981-001        POLICIA MILITAR
# 25341  2019-056448290-001        POLICIA MILITAR
# 25927  2019-001683345-001        POLICIA MILITAR
# 26355  2019-016141860-001        POLICIA MILITAR
# 25744  2019-024485114-001        POLICIA MILITAR
# 25642  2019-060338540-001        POLICIA MILITAR
# 23838  2019-000105837-001        POLICIA MILITAR
# 23734  2020-017103733-001        POLICIA MILITAR
# 23741  2020-018505657-001        POLICIA MILITAR
# ...

# %%
df_crimes.sort_values('Unid Digitação Nível 6', ascending = False)
# Out:
#               Número REDS Órgão Unidade Registro  \
# 10329  2019-048165270-001          POLICIA CIVIL
# 4334   2019-026379338-001        POLICIA MILITAR
# 7068   2019-022743800-001        POLICIA MILITAR
# 3811   2020-014562265-001        POLICIA MILITAR
# 6709   2019-058154644-001        POLICIA MILITAR
# 7095   2019-034913537-001        POLICIA MILITAR
# 1926   2019-038484929-001        POLICIA MILITAR
# 7042   2020-019171737-001        POLICIA MILITAR
# 6984   2019-031541236-001        POLICIA MILITAR
# 6917   2019-020891280-001        POLICIA MILITAR
# 6831   2020-011289830-001        POLICIA MILITAR
# 6727   2020-008368035-001        POLICIA MILITAR
# 1706   2019-032414379-001        POLICIA MILITAR
# 1510   2019-026437058-001        POLICIA MILITAR
# 3818   2020-014733736-001        POLICIA MILITAR
# 786    2019-011797083-001        POLICIA MILITAR
# 6664   2019-050323691-001        POLICIA MILITAR
# 6446   2020-017380331-001        POLICIA MILITAR
# ...

# %%
df_crimes.sort_values(by = ['Código Subclasse Nat Principal', 'Unid Digitação Nível 6'], ascending = [False, True]).head()
# Out:
#               Número REDS Órgão Unidade Registro  \
# 23062  2019-024241531-001          POLICIA CIVIL
# 9034   2019-013166850-001        POLICIA MILITAR
# 12887  2019-017818422-001        POLICIA MILITAR
# 14723  2019-004900113-001        POLICIA MILITAR
# 24987  2020-007225023-001          POLICIA CIVIL
#
#                 Unidade Área Militar  \
# 23062         141 CIA PM/7 BPM/7 RPM
# 9034   3 PEL/139 CIA PM/23 BPM/7 RPM
# 12887         53 CIA PM/23 BPM/7 RPM
# 14723  3 PEL/280 CIA PM/60 BPM/7 RPM
# 24987  2 PEL/290 CIA PM/63 BPM/7 RPM
#
#                                Unidade Relato Nível 6  \
# 23062            9ª DELEGACIA DE POLICIA CIVIL/ABAETE
# 9034                          139 CIA PM/23 BPM/7 RPM
# 12887                         139 CIA PM/23 BPM/7 RPM
# 14723                         279 CIA PM/60 BPM/7 RPM
# 24987  4ª DELEGACIA REGIONAL DE POLICIA CIVIL/FORMIGA
#
#                                Unid Digitação Nível 6  \
# ...

# %%
colunas = ['Código Subclasse Nat Principal', 'Unid Digitação Nível 6']

ordenação = [True, False]

df_crimes.sort_values
